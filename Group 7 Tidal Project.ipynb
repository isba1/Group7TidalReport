# %%
import numpy as np
from io import StringIO

data1 = np.genfromtxt("ASTR19_S22_group_project_data.txt",dtype=str,delimiter=",")
data2 = []
for data in data1:
    day,time,height = data.split()
    hour,minute = time.split(":")
    hours = (float(day)-1)*24 + float(hour) + float(minute) / 60
    data2.append((round(hours,2),float(height)))
print(data2)
# Out:
# [(8.12, 6.57), (15.62, -0.39), (32.92, 5.38), (40.42, -1.74), (57.75, 5.26), (65.23, -1.36), (82.58, 4.13), (90.0, -1.15), (107.47, 3.48), (114.77, -1.61), (132.37, 2.62), (139.52, 0.05), (157.4, 1.83), (164.27, 1.01), (171.37, 3.57), (189.02, 0.73), (196.12, 4.54), (213.77, 2.17), (220.83, 3.76), (227.97, 2.88), (245.52, 3.9), (252.93, 1.92), (270.13, 4.73), (277.75, 1.74), (294.78, 5.66), (302.42, 0.79), (319.37, 5.33), (327.0, -0.04), (343.98, 5.23), (351.57, -1.12), (368.57, 6.67), (376.13, -0.61), (393.17, 4.74), (400.68, -0.93), (417.75, 4.69), (425.2, -1.29), (442.35, 4.2), (449.75, 0.22), (466.95, 3.68), (474.25, 0.26), (491.63, 2.47), (498.8, 0.36), (516.42, 2.59), (523.33, 0.99), (530.37, 4.1), (547.87, 1.87), (554.97, 3.17), (572.5, 1.6), (579.62, 3.71), (586.73, 3.1), (604.38, 4.04), (611.92, 2.49), (629.25, 4.07), (636.95, 2.18), (654.15, 5.93), (661.83, 0.7), (679.08, 6.89), (686.65, 0.21), (703.97, 6.72), (711.45, 0.22), (728.83, 6.77), (736.17, -1.68), (753.67, 5.77), (760.87, -1.32), (778.5, 4.35), (785.57, -0.73), (803.32, 4.23), (810.2, -0.38), (828.17, 2.24), (834.82, -0.61), (841.53, 3.45), (859.4, -0.46), (866.22, 4.13), (884.0, 1.21), (890.9, 3.34), (897.9, 2.58), (915.65, 3.32), (923.25, 3.26), (940.48, 5.21), (948.37, 2.39), (965.35, 4.83), (973.23, 2.41)]
